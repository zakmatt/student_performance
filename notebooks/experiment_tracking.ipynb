# %%
# %load_ext autoreload
# %autoreload 2

# %%
# add kernel pipenv run python -m ipykernel install --user --name

# %%
import boto3
import io
import json
import mlflow
import mlflow.xgboost
import os
import pandas as pd
import xgboost as xgb

from datetime import datetime
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from mlflow import log_metric, log_param, log_artifact
from mlflow.entities import ViewType
from mlflow.tracking import MlflowClient
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from typing import Dict

# %%
DATA_PATH = "../data/student_performance_data.csv"
TARGET_COLUMN = "GPA" 
STRATIFY_COLUMN = "GradeClass"
SEED = 42

# %%
with open("../terraform_env.json", "r") as f:
    config = json.load(f)

# %%
MLFLOW_TRACKING_URI = f"postgresql://{config.get('RDS_USERNAME')}:{config.get('RDS_PASSWORD')}@{config.get('RDS_ENDPOINT')}/{config.get('RDS_DB_NAME')}"
MLFLOW_S3_BUCKET = config.get('SAVE_BUCKET')

# %%
os.environ["db_uri"] = MLFLOW_TRACKING_URI

# %%
! pipenv run mlflow db upgrade $db_uri
# Out:
# 2024/08/04 00:07:04 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size

# %%
MLFLOW_TRACKING_URI, MLFLOW_S3_BUCKET
# Out:
# ('postgresql://devadmin:devpassword123@terraform-20240803194049581800000002.cfmikes0cgsk.eu-west-1.rds.amazonaws.com:5432/devdb',
#  'dev-student-performance-model-storage-bucket')

# %%
# Set the tracking URI to the RDS PostgreSQL instance created with terraform
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set the artifact location to the S3 bucket created with terraform
artifact_location = f"s3://{MLFLOW_S3_BUCKET}/mlflow-artifacts"

# %%
client = MlflowClient()
experiment_name = "xgboost_hyperoptimization"
mlflow.create_experiment(experiment_name, artifact_location=artifact_location)
# Out:
# '5'

# %%
data = pd.read_csv(DATA_PATH)

# %%
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
TARGET_COLUMNS = ["GPA", "GradeClass"]
x = data.drop(TARGET_COLUMNS, axis=1)
y = data["GPA"]
stratify_col = data["GradeClass"]

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x, y, test_size=0.2, stratify=stratify_col, random_state=SEED
)

# %%
# Define the hyperparameter space
search_space = {
    'max_depth': hp.quniform('max_depth', 3, 10, 1),
    'learning_rate': hp.loguniform('learning_rate', -5, 0),
    'n_estimators': hp.quniform('n_estimators', 100, 500, 50),
    'subsample': hp.uniform('subsample', 0.7, 1.0),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.7, 1.0)
}

# %%
train_mtx = xgb.DMatrix(x_train, label=y_train)
valid_mtx = xgb.DMatrix(x_val, label=y_val)

# %%
def objective(params: Dict, train_mtx: xgb.DMatrix, valid_mtx: xgb.DMatrix) -> Dict:
    """
    Objective function for training an XGBoost model using specified hyperparameters.

    This function trains an XGBoost model with the provided hyperparameters, logs the model and its performance metrics to MLflow, 
    and returns the loss and status for hyperparameter optimization.

    Parameters:
    params (Dict): A dictionary of hyperparameters for training the XGBoost model. Expected keys include 'max_depth' and 'n_estimators'.
    train_mtx (xgb.DMatrix): Training data matrix in XGBoost DMatrix format.
    valid_mtx (xgb.DMatrix): Validation data matrix in XGBoost DMatrix format.

    Returns:
    Dict: A dictionary containing the loss (root mean squared error) and status for hyperparameter optimization.
    """
    
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")

        params['max_depth'] = int(params['max_depth'])
        params['n_estimators'] = int(params['n_estimators'])

        xg_booster = xgb.train(
            params=params,
            dtrain=train_mtx,
            num_boost_round=1000,
            evals=[(valid_mtx, 'validation')],
            early_stopping_rounds=50
        )
        
        # Predict and evaluate the model
        y_pred = xg_booster.predict(valid_mtx)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        
        # Log parameters and metrics
        mlflow.log_params(params)
        mlflow.log_metric("rmse", rmse)

        return {'loss': rmse, 'status': STATUS_OK}

# %%
# Initialize MLflow
current_experiment = mlflow.set_experiment(experiment_name)
experiment_id = current_experiment.experiment_id
# Out:
# <Experiment: artifact_location='s3://dev-student-performance-model-storage-bucket/mlflow-artifacts', creation_time=1722722303726, experiment_id='5', last_update_time=1722722303726, lifecycle_stage='active', name='xgboost_hyperoptimization', tags={}>

# %%
best_result = fmin(
    fn=lambda params: objective(params, train_mtx, valid_mtx),
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:0.68720
# [1]	validation-rmse:0.68431
# [2]	validation-rmse:0.54683
# [3]	validation-rmse:0.53516
# [4]	validation-rmse:0.45097
# [5]	validation-rmse:0.39522
# [6]	validation-rmse:0.35873
# [7]	validation-rmse:0.33501
# [8]	validation-rmse:0.32058
# [9]	validation-rmse:0.31962
# [10]	validation-rmse:0.31840
# [11]	validation-rmse:0.31076
# [12]	validation-rmse:0.30641
# [13]	validation-rmse:0.30169
# [14]	validation-rmse:0.29977
# [15]	validation-rmse:0.29807
# [16]	validation-rmse:0.29639
# [17]	validation-rmse:0.29526
# [18]	validation-rmse:0.29523
# [19]	validation-rmse:0.29483
# [20]	validation-rmse:0.29460
# [21]	validation-rmse:0.29449
# [22]	validation-rmse:0.29365
#   0%|                                                                                                                                                                          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/matthewzak/.local/share/virtualenvs/student_performance-tcDVmbkn/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [00:08:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [23]	validation-rmse:0.29378
# [24]	validation-rmse:0.29370
# [25]	validation-rmse:0.29356
# [26]	validation-rmse:0.29340
# [27]	validation-rmse:0.29338
# [28]	validation-rmse:0.29349
# [29]	validation-rmse:0.29358
# [30]	validation-rmse:0.29355
# [31]	validation-rmse:0.29345
# [32]	validation-rmse:0.29327
# [33]	validation-rmse:0.29341
# [34]	validation-rmse:0.29336
# [35]	validation-rmse:0.29364
# [36]	validation-rmse:0.29359
# [37]	validation-rmse:0.29381
# [38]	validation-rmse:0.29401
# [39]	validation-rmse:0.29390
# [40]	validation-rmse:0.29382
# [41]	validation-rmse:0.29396
# [42]	validation-rmse:0.29412
# [43]	validation-rmse:0.29417
# [44]	validation-rmse:0.29421
# [45]	validation-rmse:0.29420
# [46]	validation-rmse:0.29418
# [47]	validation-rmse:0.29439
# [48]	validation-rmse:0.29433
# [49]	validation-rmse:0.29433
# [50]	validation-rmse:0.29437
# [51]	validation-rmse:0.29446
# [52]	validation-rmse:0.29456
# [53]	validation-rmse:0.29463
# [54]	validation-rmse:0.29475
# [55]	validation-rmse:0.29485
# [56]	validation-rmse:0.29480
# [57]	validation-rmse:0.29469
# [58]	validation-rmse:0.29468
# [59]	validation-rmse:0.29458
# [60]	validation-rmse:0.29466
# [61]	validation-rmse:0.29474
# [62]	validation-rmse:0.29480
# [63]	validation-rmse:0.29481
# [64]	validation-rmse:0.29495
# [65]	validation-rmse:0.29496
# [66]	validation-rmse:0.29495
# [67]	validation-rmse:0.29500
# [68]	validation-rmse:0.29504
# [69]	validation-rmse:0.29509
# [70]	validation-rmse:0.29514
# [71]	validation-rmse:0.29513
# [72]	validation-rmse:0.29515
# [73]	validation-rmse:0.29508
# [74]	validation-rmse:0.29506
# [75]	validation-rmse:0.29506
# [76]	validation-rmse:0.29508
# [77]	validation-rmse:0.29512
# [78]	validation-rmse:0.29512
# [79]	validation-rmse:0.29514
# [80]	validation-rmse:0.29512
# [81]	validation-rmse:0.29513
# [82]	validation-rmse:0.29511
#   0%|                                                                                                                                                                          | 0/50 [00:01<?, ?trial/s, best loss=?]
# /Users/matthewzak/.local/share/virtualenvs/student_performance-tcDVmbkn/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [0]	validation-rmse:0.42388
# [1]	validation-rmse:0.41027
# [2]	validation-rmse:0.35114
# [3]	validation-rmse:0.34964
# [4]	validation-rmse:0.34506
# [5]	validation-rmse:0.34223
# [6]	validation-rmse:0.34300
# [7]	validation-rmse:0.34710
# [8]	validation-rmse:0.34722
# [9]	validation-rmse:0.34847
# [10]	validation-rmse:0.34832
# [11]	validation-rmse:0.34905
# [12]	validation-rmse:0.34937
# [13]	validation-rmse:0.34931
# [14]	validation-rmse:0.35062
# [15]	validation-rmse:0.35126
# [16]	validation-rmse:0.35241
# [17]	validation-rmse:0.35265
# [18]	validation-rmse:0.35274
# [19]	validation-rmse:0.35260
# [20]	validation-rmse:0.35227
# [21]	validation-rmse:0.35190
# [22]	validation-rmse:0.35183
# [23]	validation-rmse:0.35174
# [24]	validation-rmse:0.35173
# [25]	validation-rmse:0.35186
# [26]	validation-rmse:0.35187
# [27]	validation-rmse:0.35216
# [28]	validation-rmse:0.35219
# [29]	validation-rmse:0.35234
# [30]	validation-rmse:0.35231
# [31]	validation-rmse:0.35227
# [32]	validation-rmse:0.35243
# [33]	validation-rmse:0.35237
# [34]	validation-rmse:0.35240
#   2%|██▉                                                                                                                                             | 1/50 [00:03<01:54,  2.34s/trial, best loss: 0.2951126925835554]
# /Users/matthewzak/.local/share/virtualenvs/student_performance-tcDVmbkn/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [00:08:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [35]	validation-rmse:0.35238
# [36]	validation-rmse:0.35233
# [37]	validation-rmse:0.35233
# [38]	validation-rmse:0.35245
# [39]	validation-rmse:0.35247
# [40]	validation-rmse:0.35245
# [41]	validation-rmse:0.35243
# [42]	validation-rmse:0.35240
# [43]	validation-rmse:0.35240
# [44]	validation-rmse:0.35241
# [45]	validation-rmse:0.35243
# [46]	validation-rmse:0.35244
# [47]	validation-rmse:0.35243
# [48]	validation-rmse:0.35244
# [49]	validation-rmse:0.35243
# [50]	validation-rmse:0.35242
# [51]	validation-rmse:0.35242
# [52]	validation-rmse:0.35241
# [53]	validation-rmse:0.35242
# [54]	validation-rmse:0.35242
#   2%|██▉                                                                                                                                             | 1/50 [00:03<01:54,  2.34s/trial, best loss: 0.2951126925835554]
# /Users/matthewzak/.local/share/virtualenvs/student_performance-tcDVmbkn/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [0]	validation-rmse:0.88200
# [1]	validation-rmse:0.88025
# [2]	validation-rmse:0.85768
# [3]	validation-rmse:0.85593
# [4]	validation-rmse:0.83387
# [5]	validation-rmse:0.81284
# [6]	validation-rmse:0.79212
# [7]	validation-rmse:0.77179
# [8]	validation-rmse:0.75265
# [9]	validation-rmse:0.75112
# [10]	validation-rmse:0.74965
# [11]	validation-rmse:0.73112
# [12]	validation-rmse:0.71289
# [13]	validation-rmse:0.69581
# [14]	validation-rmse:0.67881
# [15]	validation-rmse:0.66290
# [16]	validation-rmse:0.64743
# [17]	validation-rmse:0.63234
# [18]	validation-rmse:0.63084
# [19]	validation-rmse:0.61641
# [20]	validation-rmse:0.61495
# [21]	validation-rmse:0.60080
# [22]	validation-rmse:0.58711
# [23]	validation-rmse:0.57431
# [24]	validation-rmse:0.57269
# [25]	validation-rmse:0.55970
# [26]	validation-rmse:0.55862
# [27]	validation-rmse:0.54575
# [28]	validation-rmse:0.53429
# [29]	validation-rmse:0.52301
# [30]	validation-rmse:0.51238
# [31]	validation-rmse:0.50113
# [32]	validation-rmse:0.49142
# [33]	validation-rmse:0.49012
# [34]	validation-rmse:0.48003
# [35]	validation-rmse:0.47089
# [36]	validation-rmse:0.46177
# [37]	validation-rmse:0.45357
# [38]	validation-rmse:0.45193
# [39]	validation-rmse:0.44355
# [40]	validation-rmse:0.43548
# [41]	validation-rmse:0.42779
# [42]	validation-rmse:0.41993
# [43]	validation-rmse:0.41277
# [44]	validation-rmse:0.40603
# [45]	validation-rmse:0.39914
# [46]	validation-rmse:0.39275
# [47]	validation-rmse:0.38647
# [48]	validation-rmse:0.38501
# [49]	validation-rmse:0.37905
# [50]	validation-rmse:0.37326
# [51]	validation-rmse:0.36744
# [52]	validation-rmse:0.36201
# [53]	validation-rmse:0.35697
# [54]	validation-rmse:0.35171
# [55]	validation-rmse:0.34730
# [56]	validation-rmse:0.34598
# [57]	validation-rmse:0.34128
# [58]	validation-rmse:0.33651
# [59]	validation-rmse:0.33252
# [60]	validation-rmse:0.32842
# [61]	validation-rmse:0.32680
# [62]	validation-rmse:0.32530
# [63]	validation-rmse:0.32405
# [64]	validation-rmse:0.31986
# [65]	validation-rmse:0.31857
# [66]	validation-rmse:0.31473
# [67]	validation-rmse:0.31133
# [68]	validation-rmse:0.30816
# [69]	validation-rmse:0.30498
# [70]	validation-rmse:0.30215
# [71]	validation-rmse:0.30097
# [72]	validation-rmse:0.30002
# [73]	validation-rmse:0.29693
#   4%|█████▊                                                                                                                                          | 2/50 [00:05<01:43,  2.15s/trial, best loss: 0.2951126925835554]
# ...
# [239]	validation-rmse:0.20596
# [240]	validation-rmse:0.20590
# [241]	validation-rmse:0.20589
# [242]	validation-rmse:0.20588
# [243]	validation-rmse:0.20590
# [244]	validation-rmse:0.20597
# [245]	validation-rmse:0.20597
# [246]	validation-rmse:0.20598
# [247]	validation-rmse:0.20608
# [248]	validation-rmse:0.20599
# [249]	validation-rmse:0.20588
# [250]	validation-rmse:0.20596
# [251]	validation-rmse:0.20596
# [252]	validation-rmse:0.20600
# [253]	validation-rmse:0.20597
# [254]	validation-rmse:0.20594
# [255]	validation-rmse:0.20597
# [256]	validation-rmse:0.20597
# [257]	validation-rmse:0.20590
# [258]	validation-rmse:0.20581
# [259]	validation-rmse:0.20580
# [260]	validation-rmse:0.20585
# [261]	validation-rmse:0.20589
# [262]	validation-rmse:0.20601
# [263]	validation-rmse:0.20601
# [264]	validation-rmse:0.20602
# [265]	validation-rmse:0.20607
# [266]	validation-rmse:0.20608
# [267]	validation-rmse:0.20609
# [268]	validation-rmse:0.20608
# [269]	validation-rmse:0.20611
# [270]	validation-rmse:0.20610
# [271]	validation-rmse:0.20615
# [272]	validation-rmse:0.20613
# [273]	validation-rmse:0.20614
# [274]	validation-rmse:0.20617
# [275]	validation-rmse:0.20612
# [276]	validation-rmse:0.20613
# [277]	validation-rmse:0.20615
# [278]	validation-rmse:0.20616
# [279]	validation-rmse:0.20623
# [280]	validation-rmse:0.20621
# [281]	validation-rmse:0.20621
# [282]	validation-rmse:0.20625
# [283]	validation-rmse:0.20626
# [284]	validation-rmse:0.20620
# [285]	validation-rmse:0.20621
# [286]	validation-rmse:0.20624
# [287]	validation-rmse:0.20629
# [288]	validation-rmse:0.20627
# [289]	validation-rmse:0.20626
# [290]	validation-rmse:0.20621
# [291]	validation-rmse:0.20623
# [292]	validation-rmse:0.20622
# [293]	validation-rmse:0.20619
# [294]	validation-rmse:0.20609
# [295]	validation-rmse:0.20613
# [296]	validation-rmse:0.20612
# [297]	validation-rmse:0.20610
# [298]	validation-rmse:0.20616
# [299]	validation-rmse:0.20618
# [300]	validation-rmse:0.20617
# [301]	validation-rmse:0.20619
# [302]	validation-rmse:0.20628
# [303]	validation-rmse:0.20632
# [304]	validation-rmse:0.20630
# [305]	validation-rmse:0.20637
# [306]	validation-rmse:0.20641
# [307]	validation-rmse:0.20643
# [308]	validation-rmse:0.20649
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 49/50 [03:05<00:03,  3.31s/trial, best loss: 0.19897295513590274]
# /Users/matthewzak/.local/share/virtualenvs/student_performance-tcDVmbkn/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [03:06<00:00,  3.73s/trial, best loss: 0.19897295513590274]

# %%
runs = client.search_runs(
    experiment_ids=[experiment_id],
    filter_string="",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=100,
    order_by=["metrics.rmse ASC"]
)

# %%
best_run = runs[0]
print(f"Best run ID: {best_run.info.run_id}, RMSE: {best_run.data.metrics['rmse']}")
# Out:
# Best run ID: 4ded625e45f6469c9bfc8510956027a3, RMSE: 0.19897295513590274

# %%
best_run.data.params
# Out:
# {'colsample_bytree': '0.7084146376368476',
#  'learning_rate': '0.02287865756458056',
#  'max_depth': '3',
#  'n_estimators': '400',
#  'subsample': '0.8077647505739515'}

# %%
def load_data(data_path: str) -> [pd.DataFrame, pd.DataFrame, pd.Series, pd.Series]:
    """Load the data and split it into training & validation
    
    Parameters:
    data_path (str): The path to the data file. The file can be in CSV format.

    Raises:
    FileNotFoundError: If the file does not exist at the specified path.
    ValueError: If the file format is not supported.
    """

    try:
        if data_path.endswith('.csv'):
            data = pd.read_csv(data_path)
        else:
            raise ValueError("Unsupported file format. Please provide a CSV file.")
    except FileNotFoundError as e:
        raise FileNotFoundError(f"The file at path {data_path} was not found.") from e


    x = data.drop([TARGET_COLUMN, STRATIFY_COLUMN], axis=1)
    y = data[TARGET_COLUMN]
    stratify_data = data[STRATIFY_COLUMN]

    x_train, x_val, y_train, y_val = train_test_split(
        x, y, test_size=0.2, stratify=stratify_data, random_state=SEED
    )

    return data

# %%
def get_hyperparam_space() -> Dict:
    """Define the hyperparameter space
    
    Returns:
    search_space (dict): Dictionary with defined 
    hyperparameters space
    """

    search_space = {
        'max_depth': hp.quniform('max_depth', 3, 10, 1),
        'learning_rate': hp.loguniform('learning_rate', -5, 0),
        'n_estimators': hp.quniform('n_estimators', 100, 500, 50),
        'subsample': hp.uniform('subsample', 0.7, 1.0),
        'colsample_bytree': hp.uniform('colsample_bytree', 0.7, 1.0)
    }

    return search_space

# %%
def upload_to_s3(s3: boto3.session.Session, bucket: str, xgb_model: xgb.Booster) -> str:
    """Save the XGBooster

    Parameters:
    s3 (boto3.session.Session): Opened client session allowing to save the model in S3
    bucket (str): Bucket path
    xgb_model (xgb.Booster): Trained xgbooster

    Raises:
    FileNotFoundError: If the file does not exist at the specified path.
    NoCredentialsError: If the credentials do not allow to open the session.

    Return:
    saved_path (str): path to the model in s3
    """
    
    try:
        # Save the model to an in-memory buffer
        buffer = io.BytesIO()
        xgb_model.save_model(buffer)
        # Reset buffer position to the beginning
        buffer.seek(0)
        todays_date = datetime.today().strftime('%Y_%m_%d')
        s3_file = f"xgboost_{todays_date}.model"
        s3.upload_file(buffer, bucket, s3_file)
        saved_path = "s3://{bucket}/{s3_file}"
        print(f"Upload Successful {s3_file} to {saved_path}")
    except FileNotFoundError:
        print(f"The file {local_file} was not found")
    except NoCredentialsError:
        print("Credentials not available")

    return saved_path

# %%
def save_trained_model_mlflow(xgb_model: xgb.Booster, params: Dict, saved_path: str) -> [str, str]:
    """
    Logs a trained XGBoost model and its parameters to MLflow and registers it with the given path.

    This function logs the model's hyperparameters, artifacts, and S3 path to MLflow,
    and registers the model under the given saved path. It starts a new MLflow run for these operations.

    Parameters:
    xgb_model (xgb.Booster): The trained XGBoost model to be logged.
    params (Dict): A dictionary of hyperparameters used for training the model.
    saved_path (str): The S3 path where the model is stored.

    Returns:
    run_id (str): The ID of the MLflow run.
    experiment_id (str): The ID of the MLflow experiment.

    Logs:
    - Parameters used for training the model.
    - The model artifact.
    - The S3 path where the model is stored.
    - Registers the model in MLflow.
    """

    # Log the model to MLflow
    with mlflow.start_run() as run:
        mlflow.log_params(params=params)
        
        # Log the model
        mlflow.log_artifact(model_path, artifact_path="model")
    
        # Optionally log the S3 path where the model is stored
        mlflow.log_param("s3_path", saved_path)
        
        # Log the model
        mlflow.xgboost.log_model(xgb_model, "student_performance_regressor")
        
        # Register the model
        model_uri = f"runs:/{run.info.run_id}/student_performance_regressor"
        mlflow.register_model(model_uri=model_uri, name="student_performance_regressor")
    
        run_id = run.info.run_id
        experiment_id = run.info.experiment_id
        print(f"Model logged in run {run_id} of experiment {experiment_id}")

    return run_id, experiment_id

# %%
def move_model_staging(client: MlflowClient, model_name: str, run_id: str):
    """
    Registers the model version from a specific run and promotes it to the staging phase in MLflow.

    This function registers a model version using the provided model name and run ID, 
    and then transitions the model version to the staging phase in MLflow Model Registry.

    Parameters:
    client (MlflowClient): The MLflow client used to interact with the MLflow tracking server.
    model_name (str): The name of the model to be registered and promoted.
    run_id (str): The ID of the MLflow run from which the model version is to be registered.

    Returns:
    None

    Actions:
    - Registers the model version from the given run ID.
    - Promotes the registered model version to the "Staging" stage in MLflow Model Registry.
    """
    
    
    model_version = client.create_model_version(
        name=model_name,
        source=f"runs:/{run_id}/{model_name}",
        run_id=run_id
    )
    
    # Transition the model version to staging
    client.transition_model_version_stage(
        name=model_name,
        version=model_version.version,
        stage="Staging"
    )
    
    print(f"Model version {model_version.version} promoted to staging")

# %%
t = set()
t.add((1,2))
t.add("\\")
t.add("/")

# %%
(1, 2) in t
# Out:
# True

# %%
t
# Out:
# {(1, 2), '/', '\\'}
